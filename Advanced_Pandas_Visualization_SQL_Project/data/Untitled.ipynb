# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3

plt.style.use('default')

# %%
customers = pd.DataFrame({
    "customer_id":[101,102,103,104,105],
    "customer_name":["Amit","Priya","Rahul","Sneha","Vikas"],
    "region":["North","South","East","West","North"],
    "segment":["Consumer","Corporate","Consumer","Home Office","Corporate"]
})

customers

products = pd.DataFrame({
    "product_id":[1,2,3,4,5],
    "product_name":["Laptop","Mouse","Keyboard","Monitor","Printer"],
    "category":["Electronics","Accessories","Accessories",
                "Electronics","Electronics"],
    "price":[60000,500,1200,15000,10000]
})

products

orders = pd.DataFrame({
    "order_id":[1001,1002,1003,1004,1005,
                1006,1007,1008,1009,1010],

    "customer_id":[101,102,103,104,105,
                   101,102,103,104,105],

    "product_id":[1,2,3,4,5,
                  2,3,1,5,4],

    "quantity":[1,3,2,1,2,
                5,4,1,1,2],

    "order_date":[
        "2024-01-05","2024-01-10","2024-02-12",
        "2024-02-20","2024-03-02","2024-03-15",
        "2024-04-01","2024-04-10","2024-05-12",
        "2024-05-20"
    ]
})

orders
